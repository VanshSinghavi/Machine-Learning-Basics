# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

# %%
from sklearn import datasets
iris = datasets.load_iris()

X = iris.data[:, 2:]
y = iris.target

# %%
from sklearn.tree import DecisionTreeClassifier

tree_clf = DecisionTreeClassifier(max_depth=2)
tree_clf.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %% [markdown]
# TODO: Plotting Graph using Graphviz

# %%
# import os
# import os.path
# def image_path(name):
#     return os.path.join(os.getcwd(), "images", name)

# %%
# from sklearn.tree import export_graphviz
# export_graphviz(
#     tree_clf,
#     out_file=image_path("iris_tree.dot"),
#     feature_names=iris.feature_names[2:],
#     class_names=iris.target_names,
#     rounded=True,
#     filled=True,
# )

# %%
# import pydot    # TODO: Plot this using graphviz's dot command
# import graphviz
# with open(image_path("iris_tree.dot")) as f:
#     dot_graph = f.read()
# graphs = pydot.graph_from_dot_data(dot_graph)
# graph = graphs[0]

# png_data = graph.create_png()
# plt.imshow(plt.imread(png_data))

# %% [markdown]
# Using sklearn's plot_tree function

# %%
from sklearn.tree import plot_tree
plot_tree(tree_clf, filled=True, feature_names=iris.feature_names[2:], class_names=iris.target_names)
# Out:
# [Text(0.4, 0.8333333333333334, 'petal width (cm) <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'petal width (cm) <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]\nclass = virginica')]

# %%
print(tree_clf.predict([[5, 1.5]]))
print(tree_clf.predict_proba([[5, 1.5]]))
# Out:
# [1]
# [[0.         0.90740741 0.09259259]]

# %% [markdown]
# Performing regression

# %%
X_quad = 2 * np.random.rand(200, 1) - 1
Y_quad = 4 * (X_quad) ** 2 - X_quad + 0.5*np.random.randn(200, 1)
plt.scatter(X_quad, Y_quad, s=10)

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor(max_depth=2)
tree_reg.fit(X_quad, Y_quad)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
plot_tree(tree_reg, filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[0] <= -0.525\nsquared_error = 1.904\nsamples = 200\nvalue = 1.255'),
#  Text(0.25, 0.5, 'x[0] <= -0.772\nsquared_error = 0.677\nsamples = 42\nvalue = 3.115'),
#  Text(0.375, 0.6666666666666667, 'True  '),
#  Text(0.125, 0.16666666666666666, 'squared_error = 0.347\nsamples = 21\nvalue = 3.755'),
#  Text(0.375, 0.16666666666666666, 'squared_error = 0.188\nsamples = 21\nvalue = 2.475'),
#  Text(0.75, 0.5, 'x[0] <= 0.702\nsquared_error = 1.066\nsamples = 158\nvalue = 0.76'),
#  Text(0.625, 0.6666666666666667, '  False'),
#  Text(0.625, 0.16666666666666666, 'squared_error = 0.508\nsamples = 125\nvalue = 0.366'),
#  Text(0.875, 0.16666666666666666, 'squared_error = 0.357\nsamples = 33\nvalue = 2.254')]

# %%
plt.scatter(X_quad, Y_quad, s=10)
X_grid = np.linspace(-1, 1, 100).reshape(-1, 1)
plt.plot(X_grid, tree_reg.predict(X_grid), color='red', linewidth=2, label='Predictions')
